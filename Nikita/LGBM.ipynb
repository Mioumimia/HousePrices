# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, KFold
import scipy
import sklearn
import lightgbm as lgb

from sklearn.metrics import mean_squared_error

# %%
pd.options.display.max_columns = 100

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %%
target_name = 'SalePrice'
target = train_df[target_name]

# %% [markdown]
# После EDA избавимся от всех переменных которые имели малый вес в использованной модели LGBM

# %%
float_columns = [
    'LotFrontage', 'LotArea', 'OverallQual', 'MasVnrArea',
     'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
      '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'TotRmsAbvGrd',
       'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch',
        'ScreenPorch', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'MoSold', 'YrSold'
]

categorical_columns = ['MSSubClass',
 'LotShape',
 'Neighborhood',
 'Condition1',
 'OverallCond',
 'Exterior1st',
 'Exterior2nd',
 'ExterCond',
 'BsmtQual',
 'BsmtExposure',
 'HeatingQC',
 'KitchenQual',
 'FireplaceQu',
 'GarageFinish',
 'PavedDrive',
 'SaleCondition', 
 'BsmtFullBath',
 'BsmtHalfBath',
 'FullBath',
 'HalfBath',
 'BedroomAbvGr',
 'Fireplaces',
 'GarageType',
 'CentralAir']

# %%
df = pd.concat((train_df, test_df), axis = 0)
df = df[float_columns+categorical_columns +['SalePrice', 'Id']]

# %%
def target_encoding(n = 9):
    categ_nunique = df[categorical_columns].nunique()
    target_encoding = categ_nunique[categ_nunique>n].index
    for col in target_encoding:
        feature_name = col + "Rank"
        df.loc[:, feature_name] = df[col].map(df.groupby(col).SalePrice.median())
        df.loc[:, feature_name] = df.loc[:, feature_name].rank(method = "dense")
        df.drop(columns = col, inplace = True)
        categorical_columns.remove(col)
    return [col + 'Rank' for col in target_encoding]
target_encoding_cols = target_encoding(9)

# %%
df[categorical_columns] = df[categorical_columns].apply(LabelEncoder().fit_transform)

scaler = RobustScaler()

df[float_columns] = scaler.fit_transform(df[float_columns])
df[float_columns] = scaler.transform(df[float_columns])

# %%
train_df = df[~df['SalePrice'].isna()]
test_df = df[df['SalePrice'].isna()].drop(columns = 'SalePrice')

# %%
def model(features, test_features, n_folds = 4):
    
    """
    
    Return
    --------
        submission (pd.DataFrame): 
            dataframe with `SK_ID_CURR` and `TARGET` probabilities
            predicted by the model.
        feature_importances (pd.DataFrame): 
            dataframe with the feature importances from the model.
        valid_metrics (pd.DataFrame): 
            dataframe with training and validation metrics (ROC AUC) for each fold and overall.
        
    """
    
    labels = np.array(features[target_name])
    features = features.drop(columns = [target_name])
        
    print('Training Data Shape: ', features.shape)
    print('Testing Data Shape: ', test_features.shape)
    
    feature_names = list(features.columns)
    
    features = np.array(features)
    test_features = np.array(test_features)
    
    k_fold = KFold(n_splits = n_folds, shuffle = True, random_state = 50)
    
    feature_importance_values = np.zeros(len(feature_names))
    
    test_predictions = np.zeros(test_features.shape[0])
    
    out_of_fold = np.zeros(features.shape[0])
    
    valid_scores = []
    train_scores = []
        
    for train_indices, valid_indices in k_fold.split(features):
        
        train_features, train_labels = features[train_indices], labels[train_indices]
        valid_features, valid_labels = features[valid_indices], labels[valid_indices]
        
        model = lgb.LGBMRegressor(n_estimators=10000, objective = 'regression', learning_rate = 0.05, 
                                   reg_alpha = 0.1, reg_lambda = 0.1, 
                                   subsample = 0.8, n_jobs = -1, random_state = 41)
        
        model.fit(train_features, train_labels, eval_metric = 'rmse',
                  eval_set = [(valid_features, valid_labels), (train_features, train_labels)],
                  eval_names = ['valid', 'train'],
                  early_stopping_rounds = 1000, verbose = 200)
        
        best_iteration = model.best_iteration_
        
        feature_importance_values += model.feature_importances_ / k_fold.n_splits
        
        test_predictions += model.predict(test_features, num_iteration = best_iteration)/ k_fold.n_splits
        
        out_of_fold[valid_indices] = model.predict(valid_features, num_iteration = best_iteration)
    
        valid_score = model.best_score_['valid']['rmse']
        train_score = model.best_score_['train']['rmse']
        
        valid_scores.append(valid_score)
        train_scores.append(train_score)
        
    submission = pd.DataFrame({target_name: test_predictions})
    
    feature_importances = pd.DataFrame({'feature': feature_names, 'importance': feature_importance_values})
    
    valid_rmse = mean_squared_error(labels, out_of_fold)
    
    valid_scores.append(valid_rmse)
    train_scores.append(np.mean(train_scores))
    
    fold_names = list(range(n_folds))
    fold_names.append('overall')
    
    metrics = pd.DataFrame({'fold': fold_names,
                            'train': train_scores,
                            'valid': valid_scores}) 
    
    return submission, feature_importances, metrics

# %%
feature_columns = categorical_columns   +target_encoding_cols + float_columns
submission, fi, metrics = model(train_df[feature_columns + ['SalePrice']], test_df[feature_columns])
# Out:
# Training Data Shape:  (1460, 46)
# Testing Data Shape:  (1459, 46)
# Training until validation scores don't improve for 1000 rounds
# [200]	train's rmse: 12508.9	train's l2: 1.56472e+08	valid's rmse: 23824.7	valid's l2: 5.67614e+08
# [400]	train's rmse: 7588.89	train's l2: 5.75912e+07	valid's rmse: 24692.7	valid's l2: 6.09728e+08
# [600]	train's rmse: 4891.82	train's l2: 2.39299e+07	valid's rmse: 25306.8	valid's l2: 6.40434e+08
# [800]	train's rmse: 3172.96	train's l2: 1.00677e+07	valid's rmse: 25507.5	valid's l2: 6.50634e+08
# [1000]	train's rmse: 2006.49	train's l2: 4.02599e+06	valid's rmse: 25582.1	valid's l2: 6.54442e+08
# Early stopping, best iteration is:
# [105]	train's rmse: 17529.7	train's l2: 3.0729e+08	valid's rmse: 23083.3	valid's l2: 5.32838e+08
# Training until validation scores don't improve for 1000 rounds
# [200]	train's rmse: 10999.6	train's l2: 1.20991e+08	valid's rmse: 30926.4	valid's l2: 9.56445e+08
# [400]	train's rmse: 6475.07	train's l2: 4.19265e+07	valid's rmse: 31070.6	valid's l2: 9.65381e+08
# [600]	train's rmse: 4205.6	train's l2: 1.76871e+07	valid's rmse: 31218.8	valid's l2: 9.74615e+08
# [800]	train's rmse: 2831.36	train's l2: 8.0166e+06	valid's rmse: 31121.2	valid's l2: 9.68532e+08
# [1000]	train's rmse: 1956.96	train's l2: 3.82967e+06	valid's rmse: 31073.9	valid's l2: 9.65586e+08
# Early stopping, best iteration is:
# [96]	train's rmse: 15727.2	train's l2: 2.47343e+08	valid's rmse: 30141.1	valid's l2: 9.08485e+08
# Training until validation scores don't improve for 1000 rounds
# [200]	train's rmse: 11562.7	train's l2: 1.33695e+08	valid's rmse: 25042.7	valid's l2: 6.27139e+08
# [400]	train's rmse: 6667.17	train's l2: 4.44512e+07	valid's rmse: 26100.7	valid's l2: 6.81248e+08
# [600]	train's rmse: 4105.64	train's l2: 1.68563e+07	valid's rmse: 26382.8	valid's l2: 6.96051e+08
# [800]	train's rmse: 2549.57	train's l2: 6.50029e+06	valid's rmse: 26508.8	valid's l2: 7.02717e+08
# [1000]	train's rmse: 1640.67	train's l2: 2.69181e+06	valid's rmse: 26510	valid's l2: 7.0278e+08
# Early stopping, best iteration is:
# [83]	train's rmse: 18614.7	train's l2: 3.46507e+08	valid's rmse: 24207.7	valid's l2: 5.86012e+08
# Training until validation scores don't improve for 1000 rounds
# [200]	train's rmse: 10679.9	train's l2: 1.14061e+08	valid's rmse: 31296	valid's l2: 9.79439e+08
# [400]	train's rmse: 6367.34	train's l2: 4.05431e+07	valid's rmse: 31286.1	valid's l2: 9.7882e+08
# [600]	train's rmse: 4140.86	train's l2: 1.71467e+07	valid's rmse: 31061.7	valid's l2: 9.64827e+08
# [800]	train's rmse: 2891.31	train's l2: 8.35969e+06	valid's rmse: 30926.1	valid's l2: 9.56421e+08
# [1000]	train's rmse: 2105.13	train's l2: 4.43157e+06	valid's rmse: 30808.1	valid's l2: 9.49138e+08
# [1200]	train's rmse: 1576.85	train's l2: 2.48646e+06	valid's rmse: 30727.4	valid's l2: 9.44172e+08
# [1400]	train's rmse: 1181.7	train's l2: 1.39642e+06	valid's rmse: 30669.5	valid's l2: 9.4062e+08
# [1600]	train's rmse: 896.721	train's l2: 804109	valid's rmse: 30626.6	valid's l2: 9.37988e+08
# [1800]	train's rmse: 675.832	train's l2: 456749	valid's rmse: 30611.2	valid's l2: 9.37044e+08
# [2000]	train's rmse: 508.058	train's l2: 258123	valid's rmse: 30600.9	valid's l2: 9.36416e+08
# [2200]	train's rmse: 380.465	train's l2: 144753	valid's rmse: 30590.3	valid's l2: 9.35764e+08
# [2400]	train's rmse: 295.488	train's l2: 87313.3	valid's rmse: 30583.8	valid's l2: 9.35367e+08
# [2600]	train's rmse: 230.862	train's l2: 53297.1	valid's rmse: 30577.5	valid's l2: 9.34983e+08
# [2800]	train's rmse: 176.009	train's l2: 30979.1	valid's rmse: 30571.3	valid's l2: 9.34605e+08
# [3000]	train's rmse: 137.83	train's l2: 18997	valid's rmse: 30566.1	valid's l2: 9.34289e+08
# [3200]	train's rmse: 106.248	train's l2: 11288.6	valid's rmse: 30560.9	valid's l2: 9.33972e+08
# [3400]	train's rmse: 83.9408	train's l2: 7046.05	valid's rmse: 30557.4	valid's l2: 9.33756e+08
# [3600]	train's rmse: 66.1989	train's l2: 4382.3	valid's rmse: 30554.9	valid's l2: 9.33604e+08
# [3800]	train's rmse: 52.1971	train's l2: 2724.54	valid's rmse: 30552.8	valid's l2: 9.33475e+08
# [4000]	train's rmse: 41.4834	train's l2: 1720.87	valid's rmse: 30551	valid's l2: 9.33361e+08
# [4200]	train's rmse: 33.4372	train's l2: 1118.05	valid's rmse: 30549.5	valid's l2: 9.33269e+08
# [4400]	train's rmse: 26.8599	train's l2: 721.453	valid's rmse: 30547.9	valid's l2: 9.33172e+08
# [4600]	train's rmse: 21.4103	train's l2: 458.403	valid's rmse: 30547	valid's l2: 9.33117e+08
# [4800]	train's rmse: 17.0751	train's l2: 291.56	valid's rmse: 30545.8	valid's l2: 9.33045e+08
# [5000]	train's rmse: 13.4791	train's l2: 181.686	valid's rmse: 30544.7	valid's l2: 9.32979e+08
# [5200]	train's rmse: 10.8888	train's l2: 118.567	valid's rmse: 30544.1	valid's l2: 9.32944e+08
# [5400]	train's rmse: 8.78299	train's l2: 77.1409	valid's rmse: 30543.7	valid's l2: 9.32918e+08
# [5600]	train's rmse: 6.80307	train's l2: 46.2817	valid's rmse: 30543.4	valid's l2: 9.32896e+08
# [5800]	train's rmse: 5.06572	train's l2: 25.6615	valid's rmse: 30543.1	valid's l2: 9.32878e+08
# [6000]	train's rmse: 3.91311	train's l2: 15.3124	valid's rmse: 30542.9	valid's l2: 9.32871e+08
# [6200]	train's rmse: 3.07918	train's l2: 9.48133	valid's rmse: 30542.8	valid's l2: 9.32864e+08
# [6400]	train's rmse: 2.42362	train's l2: 5.87394	valid's rmse: 30542.7	valid's l2: 9.32857e+08
# [6600]	train's rmse: 1.93304	train's l2: 3.73663	valid's rmse: 30542.6	valid's l2: 9.32852e+08
# [6800]	train's rmse: 1.52245	train's l2: 2.31786	valid's rmse: 30542.6	valid's l2: 9.32849e+08
# [7000]	train's rmse: 1.22875	train's l2: 1.50982	valid's rmse: 30542.5	valid's l2: 9.32847e+08
# [7200]	train's rmse: 1.00323	train's l2: 1.00648	valid's rmse: 30542.5	valid's l2: 9.32845e+08
# [7400]	train's rmse: 0.798687	train's l2: 0.6379	valid's rmse: 30542.5	valid's l2: 9.32842e+08
# [7600]	train's rmse: 0.639444	train's l2: 0.408889	valid's rmse: 30542.4	valid's l2: 9.32841e+08
# [7800]	train's rmse: 0.514116	train's l2: 0.264315	valid's rmse: 30542.4	valid's l2: 9.3284e+08
# [8000]	train's rmse: 0.420976	train's l2: 0.177221	valid's rmse: 30542.4	valid's l2: 9.32839e+08
# [8200]	train's rmse: 0.339998	train's l2: 0.115598	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [8400]	train's rmse: 0.275552	train's l2: 0.0759288	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [8600]	train's rmse: 0.227365	train's l2: 0.0516947	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [8800]	train's rmse: 0.191167	train's l2: 0.0365448	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [9000]	train's rmse: 0.158632	train's l2: 0.0251642	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [9200]	train's rmse: 0.132676	train's l2: 0.0176028	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [9400]	train's rmse: 0.10987	train's l2: 0.0120715	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [9600]	train's rmse: 0.0933192	train's l2: 0.00870847	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# [9800]	train's rmse: 0.080688	train's l2: 0.00651056	valid's rmse: 30542.4	valid's l2: 9.32837e+08
# [10000]	train's rmse: 0.0702807	train's l2: 0.00493937	valid's rmse: 30542.4	valid's l2: 9.32838e+08
# Did not meet early stopping. Best iteration is:
# [10000]	train's rmse: 0.0702807	train's l2: 0.00493937	valid's rmse: 30542.4	valid's l2: 9.32838e+08

# %%
fi, metrics
# Out:
# (             feature  importance
#  0           LotShape      319.75
#  1         Condition1      653.25
#  2        OverallCond     1043.25
#  3          ExterCond      290.25
#  4           BsmtQual      306.75
#  5       BsmtExposure      467.25
#  6          HeatingQC      470.50
#  7        KitchenQual      411.00
#  8        FireplaceQu      749.00
#  9       GarageFinish      431.25
#  10        PavedDrive      175.75
#  11     SaleCondition      437.00
#  12      BsmtFullBath      189.25
#  13      BsmtHalfBath      141.00
#  14          FullBath      168.00
#  15          HalfBath       91.50
#  16      BedroomAbvGr      398.75
#  17        Fireplaces       93.75
#  18        GarageType      299.50
#  19        CentralAir       41.00
#  20    MSSubClassRank      544.25
#  21  NeighborhoodRank     1885.50
#  22   Exterior1stRank      904.75
#  23   Exterior2ndRank      798.75
#  24       LotFrontage     6010.75
#  25           LotArea     5509.75
#  26       OverallQual     1417.00
#  27        MasVnrArea     4929.50
#  28        BsmtFinSF1     4217.00
#  29        BsmtFinSF2      758.50
#  30         BsmtUnfSF     3209.75
#  31       TotalBsmtSF     2975.75
#  32          1stFlrSF     4068.75
#  33          2ndFlrSF     2194.00
#  34         GrLivArea     5574.50
#  35      TotRmsAbvGrd      923.50
#  36        GarageArea     4344.50
#  37        WoodDeckSF     1476.50
#  38       OpenPorchSF     7185.50
#  39     EnclosedPorch      326.00
#  40       ScreenPorch      363.75
#  41         YearBuilt     1598.75
#  42      YearRemodAdd     3126.00
#  43       GarageYrBlt     2369.75
#  44            MoSold     2116.75
#  45            YrSold     1020.25,
#        fold         train         valid
#  0        0  17529.696053  2.308329e+04
#  1        1  15727.157823  3.014108e+04
#  2        2  18614.705382  2.420768e+04
#  3        3      0.070281  3.054239e+04
#  4  overall  12967.907385  7.400431e+08)

# %%
test_df
# Out:
#       LotFrontage   LotArea  OverallQual  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0       -3.210884 -2.309988        -3.25    0.000000   -0.502543       144.0
# 1       -3.208617 -2.309830        -3.00    0.004015   -0.501696         0.0
# 2       -3.224490 -2.309856        -3.25    0.000000   -0.501942         0.0
# 3       -3.215420 -2.310086        -3.00    0.000744   -0.502294         0.0
# 4       -3.294785 -2.310383        -2.50    0.000000   -0.502925         0.0
# ...           ...       ...          ...         ...         ...         ...
# 1454    -3.344671 -2.310566        -3.50    0.000000   -0.503414         0.0
# 1455    -3.344671 -2.310569        -3.50    0.000000   -0.502945         0.0
# 1456    -3.029478 -2.309487        -3.25    0.000000   -0.501136         0.0
# 1457    -3.251701 -2.310058        -3.25    0.000000   -0.502787         0.0
# 1458    -3.224490 -2.310107        -2.75    0.003495   -0.502004         0.0
#
#       BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  TotRmsAbvGrd  \
# 0     -0.798184    -1.944423 -2.116058  0.000000  -2.339899         -3.25
# 1     -0.797787    -1.942697 -2.114403  0.000000  -2.338763         -3.00
# 2     -0.798572    -1.944245 -2.115936  0.001414  -2.337976         -3.00
# 3     -0.798026    -1.944253 -2.115943  0.001368  -2.338042         -2.75
# 4     -0.796004    -1.942887 -2.114590  0.000000  -2.338892         -3.25
# ...         ...          ...       ...       ...        ...           ...
# 1454  -0.797378    -1.945720 -2.117396  0.001102  -2.339385         -3.25
# 1455  -0.798114    -1.945720 -2.117396  0.001102  -2.339385         -3.00
# 1456  -0.798971    -1.943103 -2.114804  0.000000  -2.339039         -2.75
# 1457  -0.797294    -1.944307 -2.115775  0.000000  -2.339705         -3.00
# 1458  -0.798277    -1.943983 -2.115676  0.002026  -2.337003         -2.25
#
#       GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  ScreenPorch  \
# 0      -1.871185    0.004960    -0.376735            0.0        120.0
# 1      -1.877563    0.013924    -0.369388            0.0          0.0
# 2      -1.874969    0.007511    -0.369796            0.0          0.0
# 3      -1.875153    0.012755    -0.369388            0.0          0.0
# 4      -1.874603    0.000000    -0.360000            0.0        144.0
# ...          ...         ...          ...            ...          ...
# 1454   -1.882324    0.000000    -0.376735            0.0          0.0
# 1455   -1.877960    0.000000    -0.371837            0.0          0.0
# 1456   -1.873535    0.016794    -0.376735            0.0          0.0
# 1457   -1.882324    0.002834    -0.370204            0.0          0.0
# 1458   -1.872406    0.006732    -0.366939            0.0          0.0
#
#       YearBuilt  YearRemodAdd  GarageYrBlt  MoSold  YrSold  LotShape  \
# 0    -41.542161    -51.123603   -47.129252 -1.5000 -1003.5         3
# 1    -41.543490    -51.125575   -47.130952 -1.5000 -1003.5         0
# 2    -41.526205    -51.099277   -47.108844 -1.6875 -1003.5         0
# 3    -41.525762    -51.099277   -47.108277 -1.5000 -1003.5         0
# 4    -41.528421    -51.103222   -47.111678 -1.8125 -1003.5         0
# ...         ...           ...          ...     ...     ...       ...
# 1454 -41.538172    -51.117686          NaN -1.5000 -1004.5         3
# 1455 -41.538172    -51.117686   -47.124150 -1.6250 -1004.5         3
# 1456 -41.542604    -51.100592   -47.129819 -1.3125 -1004.5         3
# 1457 -41.528421    -51.103222          NaN -1.4375 -1004.5         3
# 1458 -41.527978    -51.101907   -47.111111 -1.1875 -1004.5         3
#
#       Condition1  OverallCond  ExterCond  BsmtQual  BsmtExposure  HeatingQC  \
# 0              1            5          4         3             3          4
# 1              2            5          4         3             3          4
# 2              2            4          4         2             3          2
# 3              2            5          4         3             3          0
# 4              2            4          4         2             3          0
# ...          ...          ...        ...       ...           ...        ...
# 1454           2            6          4         3             3          2
# 1455           2            4          4         3             3          4
# 1456           2            6          4         3             3          0
# 1457           2            4          4         2             0          4
# 1458           2            4          4         2             0          0
#
#       KitchenQual  FireplaceQu  GarageFinish  PavedDrive  SaleCondition  \
# 0               3            5             2           2              4
# 1               2            5             2           2              4
# 2               3            4             0           2              4
# 3               2            2             0           2              4
# 4               2            5             1           2              4
# ...           ...          ...           ...         ...            ...
# 1454            3            5             3           2              4
# 1455            3            5             2           2              0
# 1456            3            4             2           2              0
# 1457            3            5             3           2              4
# 1458            3            4             0           2              4
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0                0             0         1         0             2
# 1                0             0         1         1             3
# 2                0             0         2         1             3
# 3                0             0         2         1             3
# 4                0             0         2         0             2
# ...            ...           ...       ...       ...           ...
# 1454             0             0         1         1             3
# 1455             0             0         1         1             3
# 1456             1             0         1         0             4
# 1457             0             1         1         0             3
# 1458             0             0         2         1             3
#
#       Fireplaces  GarageType  CentralAir    Id  MSSubClassRank  \
# 0              0           1           1  1461            11.0
# 1              0           1           1  1462            11.0
# 2              1           1           1  1463            15.0
# 3              1           1           1  1464            15.0
# 4              0           1           1  1465            14.0
# ...          ...         ...         ...   ...             ...
# 1454           0           6           1  2915             9.0
# 1455           0           4           1  2916             9.0
# 1456           1           5           1  2917            11.0
# 1457           0           6           1  2918             7.0
# 1458           1           1           1  2919            15.0
#
#       NeighborhoodRank  Exterior1stRank  Exterior2ndRank
# 0                 10.0             12.0             14.0
# 1                 10.0              6.0              3.0
# 2                 14.0             12.0             14.0
# 3                 14.0             12.0             14.0
# 4                 23.0              9.0              9.0
# ...                ...              ...              ...
# 1454               1.0             13.0             15.0
# 1455               1.0             13.0             15.0
# 1456              12.0             12.0             14.0
# 1457              12.0              9.0              4.0
# 1458              12.0              9.0              9.0
#
# [1459 rows x 47 columns]

# %%
test_df['SalePrice'] =submission

# %%
test_df.to_csv("submission.csv", columns=["Id", "SalePrice"], index=False)
